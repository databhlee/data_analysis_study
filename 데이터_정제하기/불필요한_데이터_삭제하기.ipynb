# %% [markdown]
# # **열 삭제하기**

# %% [markdown]
# **남산도서관 데이터 다운로드하기: gdown 패키지**

# %%
import  gdown
gdown.download('http://bit.ly/3RhoNho', 'ns_202104.csv', quiet=False)
# Out:
# Downloading...
# From: http://bit.ly/3RhoNho
# To: /content/ns_202104.csv
# 100%|██████████| 57.6M/57.6M [00:00<00:00, 104MB/s]
# 'ns_202104.csv'

# %% [markdown]
# **판다스 데이터프레임으로 읽어서 처음 다섯 개 행 출력하기**

# %%
import pandas as pd
ns_df = pd.read_csv('ns_202104.csv', low_memory=False)
ns_df.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN

# %% [markdown]
# **불필요한 열인 'Unnamed: 13' 삭제하기: loc 메서드 (중간에 있는 열을 제외하려면 슬라이싱을 사용하기 어려우므로 불리언 배열 사용)**

# %%
ns_book = ns_df.loc[:, '번호':'등록일자']
ns_book.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %% [markdown]
# **데이터프레임 열 이름이 저장된 columns 속성 확인하기**

# %%
print(ns_df.columns)
# Out:
# Index(['번호', '도서명', '저자', '출판사', '발행년도', 'ISBN', '세트 ISBN', '부가기호', '권',
#        '주제분류번호', '도서권수', '대출건수', '등록일자', 'Unnamed: 13'],
#       dtype='object')

# %% [markdown]
# **columns 속성은 판다스의 Index 클래스 객체이다. 이 객체의 원소는 파이썬의 리스트처럼 숫자 인덱스로 참조할 수 있다. 예를 들어 첫 번째 열 이름인 '번호'를 선택하려면 다음과 같이 쓸 수 있다.**

# %%
print(ns_df.columns[0])
# Out:
# 번호

# %% [markdown]
# **※ 원소별 비교: Index 클래스를 비롯하여 판다스 배열 성격의 객체는 어떤 값과 비교할 때 자동으로 배열에 있는 모든 원소와 하나씩 비교**

# %% [markdown]
# **원소별 비교를 활용하여 ns_df.columns에서 'Unnamed: 13' 열이 아닌 것을 표시하는 배열 만들기 (결과: 넘파이 배열)**

# %%
ns_df.columns != 'Unnamed: 13'
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False])

# %% [markdown]
# **lck 메서드와 불리언 배열**

# %%
selected_columns = ns_df.columns != 'Unnamed: 13'
ns_book = ns_df.loc[:, selected_columns]
ns_book.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %% [markdown]
# **데이터프레임 중간에 있는 '부가기호' 열 제외하기**

# %%
selected_columns = ns_df.columns != '부가기호'
ns_df.loc[:, selected_columns]
ns_book.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %% [markdown]
# **데이터프레임의 행이나 열 삭제하기: drop() 메서드 (첫 번째 매개변수: 삭제하려는 열 이름, axis 매개변수: 열 삭제는 1, 행 삭제는 0 (기본값))**

# %%
ns_book = ns_df.drop('Unnamed: 13', axis=1)
ns_book.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %% [markdown]
# **drop() 메서드는 첫 번째 매개변수에 제외할 열 이름을 리스트 형식으로 여러 개 지정할 수 있다.**

# %%
ns_book = ns_df.drop(['부가기호', 'Unnamed: 13'], axis=1)
ns_book.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN    NaN     1     0  2021-03-19

# %% [markdown]
# **※ 중간에 있는 열을 빼고 나머지 열을 선택할 때는 불리언 배열이나 drop() 메서드 사용하기**

# %% [markdown]
# **지금까지는 ns_df 데이터프레임에서 열을 삭제한 결과를 ns_book이라는 변수에 저장했다. drop() 메서드에 inplace 매개변수를 True로 지정하면 현재 선택한 데이터프레임을 바로 수정할 수도 있다.**

# %%
ns_book.drop('주제분류번호', axis=1, inplace=True) # 선택한 데이터프레임에 덮어쓴다.
ns_book.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN    권  도서권수  대출건수        등록일자
# 0     NaN  NaN     1     0  2021-03-19
# 1     NaN  NaN     1     0  2021-03-19
# 2     NaN  NaN     1     0  2021-03-19
# 3     NaN  NaN     1     0  2021-03-19
# 4     NaN  NaN     1     0  2021-03-19

# %% [markdown]
# **NaN이 하나 이상 포함된 행이나 열 삭제하기: dropna() 메서드**

# %% [markdown]
# **axis 매개변수를 1로 지정하여 ns_df 데이터프레임에서 NaN이 포함된 열을 삭제하기**

# %%
ns_book = ns_df.dropna(axis=1)
ns_book.head()
# Out:
#    번호           ISBN  도서권수  대출건수        등록일자
# 0   1  9788937444319     1     0  2021-03-19
# 1   2  9791190123969     1     0  2021-03-19
# 2   3  9788968332982     1     0  2021-03-19
# 3   4  9788970759906     1     0  2021-03-19
# 4   5  9788934990833     1     0  2021-03-19

# %% [markdown]
# **모든 값이 NaN인 열 삭제하기: dropna() 메서드의 how 매개변수를 'all'로 지정**

# %%
ns_book = ns_df.dropna(axis=1, how='all')
ns_book.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %% [markdown]
# # **행 삭제하기**

# %% [markdown]
# **행 삭제하기: drop() 메서드 (axis 매개변수는 0이므로 기본값)**

# %% [markdown]
# **처음 2개 행 삭제하기**

# %%
ns_book2 = ns_book.drop([0,1])
ns_book2.head()
# Out:
#    번호                                  도서명                    저자  \
# 2   3                나도 한 문장 잘 쓰면 바랄 게 없겠네                김선영 지음
# 3   4                              예루살렘 해변      이도 게펜 지음, 임재희 옮김
# 4   5                김성곤의 중국한시기행 : 장강·황하 편                김성곤 지음
# 5   6                        처음 읽는 음식의 세계사  미야자키 마사카츠 지음, 한세희 옮김
# 6   7  아르센 벵거 자서전 My Life in Red and White     아르센 벵거 지음, 이성모 옮김
#
#             출판사  발행년도           ISBN 세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수  \
# 2          블랙피쉬  2021  9788968332982     NaN  NaN  NaN    NaN     1     0
# 3         문학세계사  2021  9788970759906     NaN  NaN  NaN    NaN     1     0
# 4           김영사  2021  9788934990833     NaN  NaN  NaN    NaN     1     0
# 5          탐나는책  2021  9791189550370     NaN  NaN  NaN    NaN     1     0
# 6  한즈미디어(한스미디어)  2021  9791160075793     NaN  NaN  NaN    NaN     1     0
#
#          등록일자
# 2  2021-03-19
# 3  2021-03-19
# 4  2021-03-19
# 5  2021-03-19
# 6  2021-03-19

# %% [markdown]
# **[] 연산자와 슬라이싱: []연산자에 슬라이싱이나 불리언 배열을 전달하면 행을 선택한다.**

# %% [markdown]
# **인덱스가 0, 1인 행을 제외한 모든 행을 선택하기: [] 연산자에 슬라이싱 사용**

# %%
ns_book2 = ns_book[2:]
ns_book2.head()
# Out:
#    번호                                  도서명                    저자  \
# 2   3                나도 한 문장 잘 쓰면 바랄 게 없겠네                김선영 지음
# 3   4                              예루살렘 해변      이도 게펜 지음, 임재희 옮김
# 4   5                김성곤의 중국한시기행 : 장강·황하 편                김성곤 지음
# 5   6                        처음 읽는 음식의 세계사  미야자키 마사카츠 지음, 한세희 옮김
# 6   7  아르센 벵거 자서전 My Life in Red and White     아르센 벵거 지음, 이성모 옮김
#
#             출판사  발행년도           ISBN 세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수  \
# 2          블랙피쉬  2021  9788968332982     NaN  NaN  NaN    NaN     1     0
# 3         문학세계사  2021  9788970759906     NaN  NaN  NaN    NaN     1     0
# 4           김영사  2021  9788934990833     NaN  NaN  NaN    NaN     1     0
# 5          탐나는책  2021  9791189550370     NaN  NaN  NaN    NaN     1     0
# 6  한즈미디어(한스미디어)  2021  9791160075793     NaN  NaN  NaN    NaN     1     0
#
#          등록일자
# 2  2021-03-19
# 3  2021-03-19
# 4  2021-03-19
# 5  2021-03-19
# 6  2021-03-19

# %% [markdown]
# **※ [] 연산자에 슬라이딩을 사용하면 loc 메서드에 슬라이싱을 사용하는 것과는 다르게 파이썬의 슬라이싱처럼 마지막 인덱스를 포함하지 않는다.**

# %%
ns_book2 = ns_book[0:2]
ns_book2.head()
# Out:
#    번호           도서명      저자   출판사  발행년도           ISBN 세트 ISBN 부가기호    권  \
# 0   1       인공지능과 흙  김동훈 지음   민음사  2021  9788937444319     NaN  NaN  NaN
# 1   2  가짜 행복 권하는 사회  김태형 지음  갈매나무  2021  9791190123969     NaN  NaN  NaN
#
#   주제분류번호  도서권수  대출건수        등록일자
# 0    NaN     1     0  2021-03-19
# 1    NaN     1     0  2021-03-19

# %% [markdown]
# **[] 연산자와 불리언 배열: 비교 연산자를 활용해 원하는 행은 True로 표시하고 제외할 행은 False로 표시한 불리언 배열을 만들어 사용한다.**

# %% [markdown]
# **출판사가 '한빛미디어'인 행만 선택하기: [] 연산자에 불리언 배열 사용**

# %%
selected_rows = ns_df['출판사'] =='한빛미디어'
ns_book2 = ns_book[selected_rows]
ns_book2.head()
# Out:
#       번호                                                도서명  \
# 60    61       (맛있는 디자인)프리미어 프로 CC: 쉽게 배워 제대로 써먹는 유튜브 영상 편집
# 70    71         처음 배우는 애저 (Azure Portal로 배우는 애저 도입부터 활용까지)
# 88    89  맛있는 디자인 프리미어 프로 CC 2021 - 쉽게 배워 제대로 써먹는 유튜브 영상 편집
# 156  157                    실전 보고서 작성 기술 with 파워포인트, 워드, 한글
# 198  199                                    처음 배우는 리액트 네이티브
#
#                            저자    출판사  발행년도           ISBN 세트 ISBN 부가기호     권  \
# 60         정지원,심수진,윤성우,김덕영 지음  한빛미디어  2021  9791162244029     NaN    1  2021
# 70                        김도균  한빛미디어  2020  9791162243695     NaN  NaN   NaN
# 88   정지원, 심수진, 윤성우, 김덕영 (지은이)  한빛미디어  2021  9791162244029     NaN  NaN   NaN
# 156                    홍장표 지음  한빛미디어  2020  9791162243763     NaN  NaN   NaN
# 198                    김범준 지음  한빛미디어  2021  9791162243879     NaN  NaN   NaN
#
#       주제분류번호  도서권수  대출건수        등록일자
# 60   005.567     1     1  2021-03-15
# 70    005.74     1     1  2021-03-15
# ...

# %% [markdown]
# **※ loc 메서드에 불리언 배열을 사용하여 행을 선택할 수 있다.**

# %%
ns_book2 = ns_book.loc[selected_rows] # loc 메서드에 ns_book.loc[selected_row, :]처럼 명시적으로 표현 가능
ns_book2.head()
# Out:
#       번호                                                도서명  \
# 60    61       (맛있는 디자인)프리미어 프로 CC: 쉽게 배워 제대로 써먹는 유튜브 영상 편집
# 70    71         처음 배우는 애저 (Azure Portal로 배우는 애저 도입부터 활용까지)
# 88    89  맛있는 디자인 프리미어 프로 CC 2021 - 쉽게 배워 제대로 써먹는 유튜브 영상 편집
# 156  157                    실전 보고서 작성 기술 with 파워포인트, 워드, 한글
# 198  199                                    처음 배우는 리액트 네이티브
#
#                            저자    출판사  발행년도           ISBN 세트 ISBN 부가기호     권  \
# 60         정지원,심수진,윤성우,김덕영 지음  한빛미디어  2021  9791162244029     NaN    1  2021
# 70                        김도균  한빛미디어  2020  9791162243695     NaN  NaN   NaN
# 88   정지원, 심수진, 윤성우, 김덕영 (지은이)  한빛미디어  2021  9791162244029     NaN  NaN   NaN
# 156                    홍장표 지음  한빛미디어  2020  9791162243763     NaN  NaN   NaN
# 198                    김범준 지음  한빛미디어  2021  9791162243879     NaN  NaN   NaN
#
#       주제분류번호  도서권수  대출건수        등록일자
# 60   005.567     1     1  2021-03-15
# 70    005.74     1     1  2021-03-15
# ...

# %% [markdown]
# **대출건수가 1,000 이하인 행을 모두 삭제하기 (selected_rows 변수를 만들지 않고 조건을 직접 넣어 사용하기)**

# %%
ns_book2 = ns_book[ns_book['대출건수'] > 1000]
ns_book2.head()
# Out:
#             번호                                      도서명                 저자  \
# 94781    94782  사피엔스 :유인원에서 사이보그까지, 인간 역사의 대담하고 위대한 질문   유발 하라리 지음 ;조현욱 옮김
# 346944  346945                         해커스 토익:Listening       David Cho 지음
#
#              출판사  발행년도           ISBN 세트 ISBN 부가기호    권  주제분류번호  도서권수  대출건수  \
# 94781        김영사  2016  9788934972464     NaN  NaN  NaN     909    30  1468
# 346944  해커스어학연구소  2005  9788990700148     NaN    1  NaN  740.77    29  1065
#
#               등록일자
# 94781   2016-04-22
# 346944  2005-02-01

# %% [markdown]
# # **중복된 행 찾기**

# %% [markdown]
# **중복된 행 중에서 처음 행을 제외한 나머지 행은 True로, 그 외에 중복되지 않은 나머지 모든 행은 False로 표시한 불리언 배열을 반환: duplicated() 메서드**

# %% [markdown]
# **※ 파이썬의 sum() 함수를 함께 사용하면 True를 1로 인식하기 때문에 duplicated() 메서드로 만든 불리언 배열에서 중복된 행의 개수를 셀 수 있다.**

# %% [markdown]
# **불필요한 열을 정리한 ns_book 데이터프레임에 중복된 행이 있는지 확인하기**

# %%
sum(ns_book.duplicated())
# Out:
# 0

# %% [markdown]
# **일부 열을 기준으로 중복된 행을 찾기: duplicated() 메서드의 subset 매개변수에 기준을 나열**

# %%
sum(ns_book.duplicated(subset=['도서명', '저자', 'ISBN']))
# Out:
# 22096

# %% [markdown]
# **'도서명', '저자', 'ISBN'을 기준으로 어떤 데이터가 중복되었는지 확인하기: duplicated() 메서드에 keep 매개변수를 False로 지정하여 중복된 모든 행을 True로 표시 (기본값은 keep=first)**

# %%
dup_rows = ns_book.duplicated(subset=['도서명', '저자', 'ISBN'], keep=False)
ns_book3 = ns_book[dup_rows]
ns_book3.head()
# Out:
#       번호                  도서명                 저자           출판사  발행년도  \
# 109  110                  파친코     이민진 지음 ;이미정 옮김          문학사상  2018
# 110  111                  파친코     이민진 지음 ;이미정 옮김          문학사상  2018
# 111  112  보건교사 안은영 :정세랑 장편소설            지은이: 정세랑           민음사  2021
# 112  113  보건교사 안은영 :정세랑 장편소설            지은이: 정세랑           민음사  2021
# 113  114                 스토너   존 윌리엄스 지음 ;김승욱 옮김  RHK(알에이치코리아)  2021
#
#               ISBN        세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 109  9788970129815  9788970129808    0    1  843.6     1     0  2021-03-12
# 110  9788970129822  9788970129808    0    2  843.6     1     0  2021-03-12
# 111  9788937479953            NaN    0  NaN  813.7     1     0  2021-03-12
# 112  9788937479953            NaN    0  NaN  813.7     1     1  2021-03-12
# 113  9788925538297            NaN    0  NaN  843.5     1     0  2021-03-12

# %% [markdown]
# # **그룹별로 모으기**

# %% [markdown]
# **만약 같은 도서가 두 권이라면 하나로 합치기: groupby() 메서드 (by 매개변수: 행을 합칠 때 기준이 되는 열 지정**)

# %% [markdown]
# **※ 중복된 행을 합치지 않고 그냥 삭제하기: drop_duplicates() 메서드 (duplicated() 메서드와 동일하게 subset, keep 매개변수를 제공하며 현재 데이터프레임을 수정하기 위한 inplace 매개변수가 있다.)**

# %% [markdown]
# **ns_book 데이터프레임에 있는 전체 열을 사용하는 대신, 그룹으로 묶을 기준 열과 '대출건수' 열만 선택, 사용**

# %%
count_df = ns_book[['도서명', '저자', 'ISBN', '권', '대출건수']]

# %% [markdown]
# **결과를 반환한 count_df 데이터프레임에 groupby() 메서드 적용하기 (정수 타입인 '대출건수' 열은 일반적으로 더하거나 평균을 내는데, 같은 책의 대출건수는 하나로 합쳐야 하므로 sum() 메서드 사용)**

# %% [markdown]
# **※ groupby() 메서드는 기본적으로 by 매개변수에 지정된 열에 NaN이 포함되어 있으면 해당 행을 삭제한다. count_df 데이터프레임의 '도서명'이나, '저자', '권' 열에는 값이 누락되어 이따금 NaN이 포함되어 있다. NaN이 포함되어 있는 행을 삭제하고 계산하면 대출건수 합계에서 빠지기 때문에 이를 막기 위해 dropna 매개변수를 False로 지정한다. 이는 연산할 때 NaN이 있는 행도 포함하겠다는 의미이다.**

# %%
group_df = count_df.groupby(by=['도서명', '저자', 'ISBN', '권'], dropna=False)
loan_count = group_df.sum()

# %% [markdown]
# **위 코드의 두 메서드를 이어서 쓰면 어떤 작업을 수행하는지 명확하게 드러낼 수 있다.**

# %%
loan_count = count_df.groupby(by=['도서명', '저자', 'ISBN', '권'], dropna=False).sum()

# %% [markdown]
# # **원본 데이터 업데이트하기**

# %% [markdown]
# **원본 데이터프레임에는 중복된 데이터가 있다. 따라서 더해진 대출건수를 업데이트하기 전에 다음과 같은 과정을 거쳐야 한다.**

# %% [markdown]
# 1.   duplicated() 메서드로 중복된 행을 True로 표시한 불리언 배열을 만든다.
# 2.   1번에서 구한 불리언 배열을 반전시켜서 중복되지 않은 고유한 행을 True로 표시한다.
# 3.   2번에서 구한 불리언 배열을 사용해 원본 배열에서 고유한 행만 선택한다.

# %% [markdown]
# **중복된 행을 True로 표시한 불리언 배열을 반전시키기: ~연산자**

# %% [markdown]
# **원본 배열에서 고유한 배열을 선택하여 ns_book3 데이터프레임 만들기: copy() 메서드**

# %%
dup_rows = ns_book.duplicated(subset=['도서명', '저자', 'ISBN', '권'])
unique_rows = ~dup_rows
ns_book3 = ns_book[unique_rows].copy()

# %% [markdown]
# **※ copy() 메서드는 데이터프레임의 복사본을 만든다. unique_rows 배열로 일부 행을 선택하여 만든 ns_book3의 '대출건수' 열을 업데이트해야 하기 때문이다. 판다스는 copy() 메서드를 사용하지 않으면 ns_book3 데이터프레임이 별도의 메모리 공간에 저장되는지 보장하지 않는다. 따라서 명시적으로 복사하지 않고 '대출건수' 열을 업데이트하면 ns_book의 데이터가 바뀔 수도 있다. 이런 이유로 판다스에서는 일부 행이나 열을 선택하여 데이터를 업데이트할 때는 항상 복사하는 것이 좋다.**

# %% [markdown]
# **ns_book3에 중복된 행이 없는지 확인하기: duplicated() 메서드**

# %%
sum(ns_book3.duplicated(subset=['도서명', '저자', 'ISBN', '권']))
# Out:
# 0

# %% [markdown]
# **ns_book3의 인덱스를 loan_count 데이터프레임의 인덱스와 동일하게 만들기 위해 원본 데이터프레임 인덱스 설정하기**

# %% [markdown]
# **지정한 열을 인덱스로 설정할 때는 set_index() 메서드 (inplace 매개변수: True (새로운 데이터프레임을 반환하지 않고 ns_book3 데이터프레임을 수정))**

# %%
ns_book3.set_index(['도서명', '저자', 'ISBN', '권'], inplace=True)
ns_book3.head()
# Out:
#                                                           번호    출판사  발행년도  \
# 도서명                   저자               ISBN          권
# 인공지능과 흙               김동훈 지음           9788937444319 NaN   1    민음사  2021
# 가짜 행복 권하는 사회          김태형 지음           9791190123969 NaN   2   갈매나무  2021
# 나도 한 문장 잘 쓰면 바랄 게 없겠네 김선영 지음           9788968332982 NaN   3   블랙피쉬  2021
# 예루살렘 해변               이도 게펜 지음, 임재희 옮김 9788970759906 NaN   4  문학세계사  2021
# 김성곤의 중국한시기행 : 장강·황하 편 김성곤 지음           9788934990833 NaN   5    김영사  2021
#
#                                                          세트 ISBN 부가기호 주제분류번호  \
# 도서명                   저자               ISBN          권
# 인공지능과 흙               김동훈 지음           9788937444319 NaN     NaN  NaN    NaN
# 가짜 행복 권하는 사회          김태형 지음           9791190123969 NaN     NaN  NaN    NaN
# 나도 한 문장 잘 쓰면 바랄 게 없겠네 김선영 지음           9788968332982 NaN     NaN  NaN    NaN
# 예루살렘 해변               이도 게펜 지음, 임재희 옮김 9788970759906 NaN     NaN  NaN    NaN
# ...

# %% [markdown]
# **다른 데이터프레임을 사용해 원본 데이터프레임의 값 업데이트하기: update() 메서드**

# %%
ns_book3.update(loan_count)
ns_book3.head()
# Out:
#                                                           번호    출판사  발행년도  \
# 도서명                   저자               ISBN          권
# 인공지능과 흙               김동훈 지음           9788937444319 NaN   1    민음사  2021
# 가짜 행복 권하는 사회          김태형 지음           9791190123969 NaN   2   갈매나무  2021
# 나도 한 문장 잘 쓰면 바랄 게 없겠네 김선영 지음           9788968332982 NaN   3   블랙피쉬  2021
# 예루살렘 해변               이도 게펜 지음, 임재희 옮김 9788970759906 NaN   4  문학세계사  2021
# 김성곤의 중국한시기행 : 장강·황하 편 김성곤 지음           9788934990833 NaN   5    김영사  2021
#
#                                                          세트 ISBN 부가기호 주제분류번호  \
# 도서명                   저자               ISBN          권
# 인공지능과 흙               김동훈 지음           9788937444319 NaN     NaN  NaN    NaN
# 가짜 행복 권하는 사회          김태형 지음           9791190123969 NaN     NaN  NaN    NaN
# 나도 한 문장 잘 쓰면 바랄 게 없겠네 김선영 지음           9788968332982 NaN     NaN  NaN    NaN
# 예루살렘 해변               이도 게펜 지음, 임재희 옮김 9788970759906 NaN     NaN  NaN    NaN
# ...

# %% [markdown]
# **업데이트가 제대로 되었다면 인덱스 열 해제하기: reset_index() 메서드**

# %%
ns_book4 = ns_book3.reset_index()
ns_book.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %% [markdown]
# **대출건수가 잘 합쳐졌는지 확인하기**

# %% [markdown]
# **원본 데이터프레임 ns_book에서 대출건수가 100회 이상인 책의 개수 세어 보기**

# %%
sum(ns_book['대출건수']>100)
# Out:
# 2311

# %% [markdown]
# **새로 만든 ns_book4 데이터프레임에서 대출건수가 100회 이상인 책의 개수 세어 보기**

# %%
sum(ns_book4['대출건수']>100)
# Out:
# 2550

# %% [markdown]
# **인덱스 설정과 해제로 인해 달라진 열의 순서를 다시 바꾸기: []연산자**

# %%
ns_book4 = ns_book4[ns_book.columns]
ns_book4.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %% [markdown]
# **다음 작업을 위해 불필요한 데이터를 제거하여 만든 ns_book4 데이터프레임 저장하기**

# %%
ns_book4.to_csv('ns_book4.csv', index=False)

# %% [markdown]
# # **일괄 처리 함수 만들기**

# %% [markdown]
# **불필요한 행과 열을 제거하기 위해 작성했던 코드를 새로운 데이터에 적용하기 쉽도록 일괄 처리하는 data_cleaning()이라는 함수 만들기**

# %%
def data_cleaning(filename):
  """
  남산 도서관 장서 CSV 데이터 전처리 함수
  :param filename: CSV 파일 이름
  """
  # 파일을 데이터프레임으로 읽는다.
  ns_df = pd.read_csv(filename, low_memory=False)
  # NaN인 열을 삭제한다.
  ns_book = ns_df.dropna(axis=1, how='all')
  # 대출건수를 합치기 위해 필요한 행만 추출하여 count_df 데이터프레임을 만든다.
  count_df = ns_book[['도서명', '저자', 'ISBN', '권', '대출건수']]
  # 도서명, 저자, ISBN, 권을 기준으로 대출건수를 groupby한다.
  loan_count = count_df.groupby(by=['도서명', '저자', 'ISBN', '권'], dropna=False).sum()
  # 원본 데이터프레임에서 중복된 행을 제외하고 고유한 행만 추출하여 복사한다.
  dup_rows = ns_book.duplicated(subset=['도서명', '저자', 'ISBN', '권'])
  unique_rows = ~dup_rows
  ns_book3 = ns_book[unique_rows].copy()
  # 도서명, 저자, ISBN, 권을 인덱스로 설정한다.
  ns_book3.set_index(['도서명', '저자', 'ISBN', '권'], inplace=True)
  # loan_count에 저장된 누적 대출건수를 업데이트한다.
  ns_book3.update(loan_count)
  # 인덱스를 재설정한다.
  ns_book4 = ns_book3.reset_index()
  # 원본 데이터프레임의 열 순서로 변경한다.
  ns_book4 = ns_book4[ns_book.columns]
  return ns_book4

# %% [markdown]
# **이 함수가 제대로 동작하는지 확인해 보기 (다른 데이터프레임을 비교할 때는 equals() 메서드 사용)**

# %%
new_ns_book4 = data_cleaning('ns_202104.csv')
ns_book4.equals(new_ns_book4)
# Out:
# True
